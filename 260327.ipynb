# %%
height1 = float(input("학생1의 키(cm)를 입력하세요."))
height2 = float(input("학생2의 키(cm)를 입력하세요."))
if height1 > height2:
  print("첫번째 학생이 더 크다.")
else:
  print("두번째 학생이 더 크다.")
# Out:
# 학생1의 키(cm)를 입력하세요.170
# 학생2의 키(cm)를 입력하세요.180
# 두번째 학생이 더 크다.

# %%
height1 = float(input("학생1의 키(cm)를 입력하세요."))
height2 = float(input("학생2의 키(cm)를 입력하세요."))
if height1 == height2:
  print("두 학생의 키는 같다.")
if height1 > height2:
   print("첫번째 학생이 더 크다.")
if height1 < height2:
   print("두번째 학생이 더 크다.")
# Out:
# 학생1의 키(cm)를 입력하세요.170
# 학생2의 키(cm)를 입력하세요.160
# 첫번째 학생이 더 크다.

# %%
height1 = float(input("학생1의 키(cm)를 입력하세요."))
height2 = float(input("학생2의 키(cm)를 입력하세요."))
if height1 == height2:
  print("두 학생의 키는 같다.")
elif height1 > height2:
  print("첫번째 학생이 더 크다.")
else:
  print("두번째 학생이 더 크다.")
# Out:
# 학생1의 키(cm)를 입력하세요.170
# 학생2의 키(cm)를 입력하세요.165
# 첫번째 학생이 더 크다.

# %%
score = int(input("점수를 입력하세요."))
if score >= 90:
  print("당신의 점수는 A입니다.")
elif score >= 80:
  print("당신의 점수는 B입니다.")
elif score >= 70:
  print("당신의 점수는 C입니다.")
else:
  print("당신의 점수는 D입니다.")
# Out:
# 점수를 입력하세요.69
# 당신의 점수는 D입니다.

# %%
import random

dice1=random.randint(1,6)
dice2=random.randint(1,6)

print(f'주사위1:{dice1}')
print(f'주사위2:{dice2}')

if dice1 == dice2:
  print("두 주사위의 숫자가 같습니다.")
elif dice1 > dice2:
  print("주사위 1이 이겼습니다.")
else:
  print("주사위 2가 이겼습니다.")
# Out:
# 주사위1:5
# 주사위2:1
# 주사위 1이 이겼습니다.

# %%
y=int(input("연도를 입력하세요."))
if(y%400==0)or(y%4==0 and y&100!=0):
  print("윤년")
else:
  print("평년")
# Out:
# 연도를 입력하세요.2024
# 윤년

# %%
import random #가위바위보

rps1=random.randint(1,3)
rps2=random.randint(1,3)
if rps1==rps2:
  print("두 사람은 비겼습니다.")
elif rps1==1 and rpx==2:
  print("두번째 사람이 이겼습니다.")
elif
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7100/1616207057.py in <cell line: 0>()
#       5 rpx1=random.randint(1,3)
#       6 rpx2=random.randint(1,3)
# ----> 7 if rps1==rps2:
#       8   print("두 사람은 비겼습니다.")
#       9 elif rps1==1 and rpx==2:
#
# NameError: name 'rps1' is not defined

# %%
def hello():
  print("안녕하세요.")

# %%
hello() #재사용
# Out:
# 안녕하세요.

# %%
def hello(irum,age):  # irum,age : 매개변수
  age+=1
  print(f"{irum}님 {age}세 안녕하세요.")
  return age

# %%
hello("홍길동", 23)
# Out:
# 홍길동님 24세 안녕하세요.
# 24
