# %%
a=7
b=11
c=a
a=b
b=c

# %%
a
# Out:
# 11

# %%
b
# Out:
# 7

# %%
a=7
b=11
a,b=b,a

# %%
a
# Out:
# 11

# %%
b
# Out:
# 7

# %%
a=input()

# %%
b=input()

# %%
a+b

# %%
a-b

# %%
int(25.5)+int(25.5)

# %%
int(25.5)-int(25.5)

# %%
1. print("a=",a)
2. print("b=",b)
3. print("c=",c)

# %%
a=100
b=a//60
c=a%60

print(f "{a}는 {b}시간 {C}분입니다.")

# %%
b
# Out:
# 1.6666666666666667

# %%
a=100
b=a//60
c=a%60
print(f"{a}는 {b}시간 {C}분입니다")

# %%
num > 0
 print("양수입니다")
num < 0
 print("음수입니다")

# %%
A=2000*a
B=3000*b
C=2500*c
D=2800*d
print(f"{A+B+C+D}원입니다")
